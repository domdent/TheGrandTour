# %%
import numpy as np
import pandas as pd
import time
from sklearn.svm import SVC,LinearSVC
from sklearn.multiclass import OneVsRestClassifier

########READ in Data########
readdata = pd.read_csv("/Users/academic/Desktop/TheGrandTour/data/wineData.txt", sep="\t", header=None);
data = np.array(readdata);
data = np.delete(data, 0, 0)
data = np.swapaxes(data,0,1)


# Need to seperate the classification dimension:
classIndex = np.shape(data)[0] - 1
classification = data[classIndex]
data = np.delete(data, classIndex, axis=0)
data = data.astype(float)


# Make list of colours for each number:
colour = np.chararray((len(classification)),unicode = True)
for i in range(len(classification)):
    if classification[i] == '1':
        colour[i] = 'r'
    elif classification[i] == '2':
        colour[i] = 'b'
    elif classification[i] == '3':
        colour[i] = 'g'


# Normalise data
for i in range(0, np.shape(data)[0]):
    data[i,:] = data[i,:] - np.min(data[i,:])
    data[i,:] = (data[i,:]/np.ndarray.max(data[i,:]))*2 - 1

d = np.shape(data)[0]
nPoints = np.shape(data)[1]

# %%
def step(coord,n,stepSize):
    coord[n] = coord[n] + stepSize
    return coord

def getPolars(coord):
    polars = np.zeros((2,d))
    for i in range(d):
        polars[0,i] = coord[i]
    polars[1,0] = coord[0] + np.pi/2
    j = 1
    for i in range(d,2*d - 1):
        polars[1,j] = coord[i]
        j += 1
    return polars 

def getX(coord):
    polars = getPolars(coord)
    X = np.ones((2,d))
    for i in range(0,2):
            for j in range(0,d):
                if j != d-1:
                    X[i,j] = np.cos(polars[i,j])
                else:
                    X[i,j] = np.sin(polars[i,j-1])
                k = j    
                while k > 0:
                    k -= 1
                    X[i,j] = X[i,j]*np.sin(polars[i,k])
                
    return X

def Transform(data, coord):
    nPoints = np.shape(data)[1]
    a = np.zeros((2,nPoints))
    X = getX(coord)  
    for p in range(0,nPoints):
        a[0,p] = np.dot(X[0],data[:,p])
        a[1,p] = np.dot(X[1],data[:,p])
    return a

def SVM(a):   
    xData = a[0]
    yData = a[1]
    nData = np.vstack((xData, yData)).T
    clf = OneVsRestClassifier(SVC(kernel='linear'), n_jobs=-1)
    clf.fit(nData, classification)
    score = clf.score(nData, classification)
    return score

# %%
coord = np.arange(0,(2*d-1))
nSteps = 100
stepSize = 0.1

tData = np.zeros((0,2,nPoints))
A = np.zeros((1,2,nPoints))
n = 0
score = 0
for t in range(nSteps):
    if n % (2*d-1) == 0:
        n = 0
    coord = step(coord,n,stepSize)
    a = Transform(data,coord)
    A[0] = a
    tData = np.append(tData,A,axis = 0)
    tscore = SVM(a)
    print(tscore)
    if tscore > score:
        score = tscore       
    if tscore < score:
        coord = step(coord,n,-2*stepSize)
    print(score)
    n += 1
# Out:
# 0.7078651685393258
# 0.7078651685393258
# 0.7078651685393258
# 0.7078651685393258
# 0.7078651685393258
# 0.7078651685393258
# 0.7078651685393258
# 0.7078651685393258
# 0.7078651685393258
# 0.7078651685393258
# 0.7078651685393258
# 0.7078651685393258
# 0.7078651685393258
# 0.7078651685393258
# 0.7078651685393258
# 0.7078651685393258
# 0.7078651685393258
# 0.7078651685393258
# 0.7078651685393258
# 0.7078651685393258
# 0.7078651685393258
# 0.7078651685393258
# Process ForkPoolWorker-4446:
# Process ForkPoolWorker-4445:
# Process ForkPoolWorker-4447:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-1589da5253bc> in <module>()
#      14     A[0] = a
#      15     tData = np.append(tData,A,axis = 0)
# ---> 16     tscore = SVM(a)
#      17     print(tscore)
#      18     if tscore > score:
#
# <ipython-input-3-b079f77c6cbe> in SVM(a)
#      44     nData = np.vstack((xData, yData)).T
#      45     clf = OneVsRestClassifier(SVC(kernel='linear'), n_jobs=-1)
# ---> 46     clf.fit(nData, classification)
#      47     score = clf.score(nData, classification)
#      48     return score
#
# /Users/karanmukhi/anaconda3/lib/python3.6/site-packages/sklearn/multiclass.py in fit(self, X, y)
#     213                 "not %s" % self.label_binarizer_.classes_[i],
#     214                 self.label_binarizer_.classes_[i]])
# --> 215             for i, column in enumerate(columns))
#     216
#     217         return self
#
# /Users/karanmukhi/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     747         self._aborting = False
#     748         if not self._managed_backend:
# --> 749             n_jobs = self._initialize_backend()
#     750         else:
#     751             n_jobs = self._effective_n_jobs()
#
# /Users/karanmukhi/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _initialize_backend(self)
#     545         try:
#     546             n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# --> 547                                              **self._backend_args)
#     548             if self.timeout is not None and not self._backend.supports_timeout:
#     549                 warnings.warn(
#
# /Users/karanmukhi/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in configure(self, n_jobs, parallel, **backend_args)
#     315         # Make sure to free as much memory as possible before forking
#     316         gc.collect()
# --> 317         self._pool = MemmapingPool(n_jobs, **backend_args)
#     318         self.parallel = parallel
#     319         return n_jobs
#
# /Users/karanmukhi/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py in __init__(self, processes, temp_folder, max_nbytes, mmap_mode, forward_reducers, backward_reducers, verbose, context_id, prewarm, **kwargs)
#     598             backward_reducers=backward_reducers)
#     599         poolargs.update(kwargs)
# --> 600         super(MemmapingPool, self).__init__(**poolargs)
#     601
#     602     def terminate(self):
#
# /Users/karanmukhi/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py in __init__(self, processes, forward_reducers, backward_reducers, **kwargs)
#     418         poolargs = dict(processes=processes)
#     419         poolargs.update(kwargs)
# --> 420         super(PicklingPool, self).__init__(**poolargs)
#     421
#     422     def _setup_queues(self):
#
# /Users/karanmukhi/anaconda3/lib/python3.6/multiprocessing/pool.py in __init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     180         self._worker_handler.daemon = True
#     181         self._worker_handler._state = RUN
# --> 182         self._worker_handler.start()
#     183
#     184
#
# /Users/karanmukhi/anaconda3/lib/python3.6/threading.py in start(self)
#     849                 del _limbo[self]
#     850             raise
# --> 851         self._started.wait()
#     852
#     853     def run(self):
#
# /Users/karanmukhi/anaconda3/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /Users/karanmukhi/anaconda3/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
#   File "/Users/karanmukhi/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/karanmukhi/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/karanmukhi/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/karanmukhi/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/karanmukhi/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/karanmukhi/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/karanmukhi/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/karanmukhi/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/karanmukhi/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/karanmukhi/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
#   File "/Users/karanmukhi/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 360, in get
#     racquire()
#   File "/Users/karanmukhi/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/pool.py", line 362, in get
#     return recv()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/karanmukhi/anaconda3/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/Users/karanmukhi/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/karanmukhi/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt

# %%
tData = np.zeros((0,2,nPoints))
A = np.zeros((1,2,nPoints))
nSteps = 100
for i in range(nSteps):
    a = Transform(data,polars+dpolars*i)
    A[0] = a
    tData = np.append(tData,A,axis = 0)

# %%
from pyqtgraph.Qt import QtGui, QtCore
import pandas as pd
import pyqtgraph as pg
import time
import sys

if __name__ == '__main__':
    
    app = 0
    app = QtGui.QApplication([])
    mw = QtGui.QMainWindow()
    mw.resize(800,800)
    view = pg.GraphicsLayoutWidget()  ## GraphicsView with GraphicsLayout inserted by default
    mw.setCentralWidget(view)
    mw.show()
    mw.setWindowTitle('pyqtgraph example: ScatterPlot')

    ## create four areas to add plots
    w1 = view.addPlot()


    ## There are a few different ways we can draw scatter plots; each is optimized for different types of data:


    ## 1) All spots identical and transform-invariant (top-left plot). 
    ## In this case we can get a huge performance boost by pre-rendering the spot 
    ## image and just drawing that image repeatedly.
    nPoints = np.shape(tData)[2]
    s1 = pg.ScatterPlotItem(size=10, pen=pg.mkPen(None), brush=pg.mkBrush(0, 227, 17,120))
    pos = np.zeros((2,nPoints))
    j = 0
    pos[0,:] = tData[j,0,:]
    pos[1,:] = tData[j,1,:]
    spots = [{'pos': pos[:,i], 'data': 1} for i in range(nPoints)]
    s1.addPoints(spots)
    w1.addItem(s1)

    def update():
        global j
        j += 1
        if j > np.shape(tData)[0]-1:
            j = 0
        pos[0,:] = tData[j,0,:]
        pos[1,:] = tData[j,1,:]
        spots = [{'pos': pos[:,i], 'data': 1} for i in range(nPoints)]
        s1.setData(spots)

    t = QtCore.QTimer()
    t.timeout.connect(update)
    t.start(20)

    ## 2) Spots are transform-invariant, but not identical (top-right plot). 
    ## In this case, drawing is almsot as fast as 1), but there is more startup 
    ## overhead and memory usage since each spot generates its own pre-rendered 
    ## image.
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Users/karanmukhi/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2971: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
